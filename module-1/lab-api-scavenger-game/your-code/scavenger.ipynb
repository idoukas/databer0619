# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/databer0619/forks' #auth:idoukas

# %%
response = requests.get(url)
results = response.json()
results

#data = response.json()
# Out:
# [{'id': 192321664,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTIzMjE2NjQ=',
#   'name': 'databer0619',
#   'full_name': 'NachoMartinezJ/databer0619',
#   'private': False,
#   'owner': {'login': 'NachoMartinezJ',
#    'id': 27884808,
#    'node_id': 'MDQ6VXNlcjI3ODg0ODA4',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/27884808?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NachoMartinezJ',
#    'html_url': 'https://github.com/NachoMartinezJ',
#    'followers_url': 'https://api.github.com/users/NachoMartinezJ/followers',
#    'following_url': 'https://api.github.com/users/NachoMartinezJ/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/NachoMartinezJ/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/NachoMartinezJ/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/NachoMartinezJ/subscriptions',
#    'organizations_url': 'https://api.github.com/users/NachoMartinezJ/orgs',
# ...

# %%
data = pd.DataFrame(results)
data.head(10)
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/NachoMartinezJ/da...     False
# 1  https://api.github.com/repos/mateusexel/databe...     False
# 2  https://api.github.com/repos/sveninja/databer0...     False
# 3  https://api.github.com/repos/jonasgranath/data...     False
# 4  https://api.github.com/repos/idoukas/databer06...     False
# 5  https://api.github.com/repos/daphn3k/databer06...     False
# 6  https://api.github.com/repos/MultiSpreeWG/data...     False
# 7  https://api.github.com/repos/LTpablo/databer06...     False
# 8  https://api.github.com/repos/TheManohar/databe...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/NachoMartinezJ/da...
# 1  https://api.github.com/repos/mateusexel/databe...
# 2  https://api.github.com/repos/sveninja/databer0...
# 3  https://api.github.com/repos/jonasgranath/data...
# 4  https://api.github.com/repos/idoukas/databer06...
# ...

# %%
# data = json_normalise(data)

# %%
data.columns
# Out:
# Index(['archive_url', 'archived', 'assignees_url', 'blobs_url', 'branches_url',
#        'clone_url', 'collaborators_url', 'comments_url', 'commits_url',
#        'compare_url', 'contents_url', 'contributors_url', 'created_at',
#        'default_branch', 'deployments_url', 'description', 'disabled',
#        'downloads_url', 'events_url', 'fork', 'forks', 'forks_count',
#        'forks_url', 'full_name', 'git_commits_url', 'git_refs_url',
#        'git_tags_url', 'git_url', 'has_downloads', 'has_issues', 'has_pages',
#        'has_projects', 'has_wiki', 'homepage', 'hooks_url', 'html_url', 'id',
#        'issue_comment_url', 'issue_events_url', 'issues_url', 'keys_url',
#        'labels_url', 'language', 'languages_url', 'license', 'merges_url',
#        'milestones_url', 'mirror_url', 'name', 'node_id', 'notifications_url',
#        'open_issues', 'open_issues_count', 'owner', 'private', 'pulls_url',
#        'pushed_at', 'releases_url', 'size', 'ssh_url', 'stargazers_count',
# ...

# %%
data1 = [];

for language in data['language']:
    if language not in data1:
        data1.append(language);
        
print(data1)
# Out:
# ['Jupyter Notebook']

# %%
data['git_commits_url'].value_counts()
# Out:
# https://api.github.com/repos/MultiSpreeWG/databer0619/git/commits{/sha}      1
# https://api.github.com/repos/LTpablo/databer0619/git/commits{/sha}           1
# https://api.github.com/repos/sveninja/databer0619/git/commits{/sha}          1
# https://api.github.com/repos/NachoMartinezJ/databer0619/git/commits{/sha}    1
# https://api.github.com/repos/idoukas/databer0619/git/commits{/sha}           1
# https://api.github.com/repos/TheManohar/databer0619/git/commits{/sha}        1
# https://api.github.com/repos/mateusexel/databer0619/git/commits{/sha}        1
# https://api.github.com/repos/jonasgranath/databer0619/git/commits{/sha}      1
# https://api.github.com/repos/daphn3k/databer0619/git/commits{/sha}           1
# Name: git_commits_url, dtype: int64

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/databer0619/commits')
results = response.json()
results
# Out:
# [{'sha': 'd87ae21cafc284bd9f5af9347c16a5b8b4210b67',
#   'node_id': 'MDY6Q29tbWl0MTg4NDU5NzU2OmQ4N2FlMjFjYWZjMjg0YmQ5ZjVhZjkzNDdjMTZhNWI4YjQyMTBiNjc=',
#   'commit': {'author': {'name': 'Manohar Sitapati',
#     'email': 'manohar.sitapati@gmail.com',
#     'date': '2019-06-17T13:33:10Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2019-06-17T13:33:10Z'},
#    'message': 'correct',
#    'tree': {'sha': '0a5b8fdf066fc3b0a94d5af47d72f7db7ba98229',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/databer0619/git/trees/0a5b8fdf066fc3b0a94d5af47d72f7db7ba98229'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/databer0619/git/commits/d87ae21cafc284bd9f5af9347c16a5b8b4210b67',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
# ...

# %%
data = response.json();
commits = json.normalize(data)
commits['commit.author.date']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-3ac5d69f02b3> in <module>
#       1 data = response.json();
# ----> 2 commits = json.normalize(data)
#       3 commits['commit.author.date']
#
# AttributeError: module 'json' has no attribute 'normalize'

# %%
len(commits)
